# %% [markdown]
# <a href="https://colab.research.google.com/github/Vieira-Miranda/engenharia_de_prompt_aplicacoes_ai/blob/main/aula07_ProgramacaoAssistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula: Programação Assistida
# Nome: Ramon Vieira Miranda (Turma Sextou)

# %%
numeros = [10, 20, 30, 40, 50] # Define uma lista de números de exemplo
soma = sum(numeros) # Usa a função embutida 'sum()' para calcular a soma de todos os elementos na lista 'numeros'
print(f"A soma dos números é: {soma}") # Imprime a soma calculada, formatando a saída com uma f-string
# Out:
# A soma dos números é: 150
