# %% [markdown]
# <a href="https://colab.research.google.com/github/Vieira-Miranda/engenharia_de_prompt_aplicacoes_ai/blob/main/aula07_ProgramacaoAssistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula

# %%
function calcularMedia(listaValores) {
    let some = 0;
    for (let valor of listaValores) {
        soma += valor;
    }
    return soma /listaValores.length;
}
