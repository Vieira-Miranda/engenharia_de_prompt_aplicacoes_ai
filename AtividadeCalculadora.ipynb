# %% [markdown]
# <a href="https://colab.research.google.com/github/Vieira-Miranda/engenharia_de_prompt_aplicacoes_ai/blob/main/AtividadeCalculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Função para realizar os cálculos
def calculadora():
    print("Selecione a operação:")
    print("1 - Soma")
    print("2 - Subtração")
    print("3 - Multiplicação")
    print("4 - Divisão")

    # Solicita a opção do usuário
    escolha = input("Digite a opção (1/2/3/4): ")

    # Verifica se a opção é válida
    if escolha in ('1', '2', '3', '4'):
        try:
            num1 = float(input("Digite o primeiro número: "))
            num2 = float(input("Digite o segundo número: "))
        except ValueError:
            print("Entrada inválida. Por favor, digite um número.")
            return

        if escolha == '1':
            print(f"Resultado: {num1} + {num2} = {num1 + num2}")
        elif escolha == '2':
            print(f"Resultado: {num1} - {num2} = {num1 - num2}")
        elif escolha == '3':
            print(f"Resultado: {num1} * {num2} = {num1 * num2}")
        elif escolha == '4':
            if num2 != 0:
                print(f"Resultado: {num1} / {num2} = {num1 / num2}")
            else:
                print("Erro: Divisão por zero!")
    else:
        print("Opção inválida")

# Executa a calculadora
calculadora()
# Out:
# Selecione a operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# Digite a opção (1/2/3/4): 1
# Digite o primeiro número: 40
# Digite o segundo número: 475
# Resultado: 40.0 + 475.0 = 515.0
